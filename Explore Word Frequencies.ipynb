# %%
import pandas as pd
from scipy import spatial
from openpyxl import load_workbook
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from library import start

# %%
clean_filepath = start.clean_filepath

# %%
docs = pd.read_csv(clean_filepath + 'text_transcripts.csv')
docs = docs.set_index('doc')

# %%
techniques = ['_stop', '_stop_wgt', '_stem', '_stem_stop', '_stem_stop_wgt', '_lsa', '_lsa_stop', '_lsa_wgt_stop']

# %% [markdown]
# ## Set pre-processing of interest and import matrix

# %%
matrix_transcripts_file = 'matrix_transcripts_lsa_stop.csv'
matrix_scripts_file = 'matrix_scripts_lsa_stop.csv'
topics_file = 'lsa_stop_topics.csv'

# %%
matrix_transcripts = pd.read_csv(clean_filepath + matrix_transcripts_file)
matrix_transcripts = matrix_transcripts.set_index('doc')
matrix_transcripts.head()
# Out:
#                               0         1         2         3         4  \
# doc
# 68_c_Transcript.docx   0.628542 -0.350509  0.083802 -0.318494 -0.163030
# 90_c_Transcript.docx   0.669009 -0.334230  0.116053 -0.233790 -0.041996
# 122_c_Transcript.docx  0.593927 -0.373292  0.286311 -0.126166 -0.302240
# 12_c_Transcript.docx   0.590151 -0.293959  0.070318 -0.073973 -0.173875
# 113_c_Transcript.docx  0.642546 -0.359431  0.222182 -0.219779  0.074334
#
#                               5         6         7         8         9  ...  \
# doc                                                                      ...
# 68_c_Transcript.docx   0.038318  0.082333  0.252457 -0.029988 -0.131897  ...
# 90_c_Transcript.docx   0.033117 -0.067874 -0.046766 -0.099285  0.062094  ...
# 122_c_Transcript.docx -0.019503  0.004667  0.153041  0.008615 -0.055725  ...
# 12_c_Transcript.docx  -0.014849 -0.022558  0.085463 -0.094699 -0.032562  ...
# 113_c_Transcript.docx  0.168001 -0.101566  0.023903 -0.103592 -0.032868  ...
#
#                              90        91        92        93        94  \
# doc
# 68_c_Transcript.docx  -0.032332 -0.011340  0.055192  0.008693  0.010974
# 90_c_Transcript.docx   0.052852  0.073113  0.050349  0.040452  0.008791
# 122_c_Transcript.docx  0.082353  0.011091  0.015251 -0.103821 -0.021088
# 12_c_Transcript.docx   0.068643  0.056804 -0.074281  0.049042 -0.078821
# 113_c_Transcript.docx  0.022270  0.051272  0.012543 -0.069186  0.028054
#
#                              95        96        97        98        99
# doc
# 68_c_Transcript.docx  -0.003002 -0.043920 -0.032214 -0.071731 -0.016648
# 90_c_Transcript.docx  -0.011361  0.013806 -0.003666 -0.038813 -0.032981
# 122_c_Transcript.docx  0.014867  0.078008  0.041382  0.042136 -0.027652
# 12_c_Transcript.docx   0.042459  0.006594  0.012062  0.019293  0.046948
# 113_c_Transcript.docx  0.045708  0.018350 -0.052213 -0.002908 -0.016798
#
# [5 rows x 100 columns]

# %%
matrix_scripts = pd.read_csv(clean_filepath + matrix_scripts_file)
matrix_scripts = matrix_scripts.set_index('doc')
matrix_scripts.head()
# Out:
#                                 0         1         2         3         4  \
# doc
# Feedback Model C22.docx  0.512281 -0.290224 -0.152412  0.243548 -0.238556
# Feedback Model D21.docx  0.436118 -0.495929 -0.248477  0.271789 -0.157235
# Feedback Model A22.docx  0.493254 -0.476017 -0.344168  0.300932 -0.034799
# Feedback Model B11.docx  0.444534 -0.523210 -0.396202  0.357982  0.045669
# Feedback Model C12.docx  0.520611 -0.280116 -0.155644  0.244462 -0.236097
#
#                                 5         6         7         8         9  \
# doc
# Feedback Model C22.docx -0.038534 -0.101865  0.010880  0.055679 -0.040573
# Feedback Model D21.docx -0.030228  0.077344  0.180670  0.042368 -0.057505
# Feedback Model A22.docx -0.010202  0.090161  0.158146  0.075198 -0.038615
# Feedback Model B11.docx -0.047634  0.155570  0.131209  0.035382 -0.048386
# Feedback Model C12.docx -0.036916 -0.111999  0.022172  0.052813 -0.048076
#
#                          ...        90        91        92        93  \
# doc                      ...
# Feedback Model C22.docx  ... -0.019766 -0.009136  0.024823 -0.017092
# Feedback Model D21.docx  ... -0.026362 -0.005423 -0.028882  0.009753
# Feedback Model A22.docx  ...  0.032167  0.036950  0.060578 -0.018571
# Feedback Model B11.docx  ... -0.019427  0.006651  0.000179  0.001871
# Feedback Model C12.docx  ... -0.020142 -0.006981  0.024795 -0.011750
#
#                                94        95        96        97        98  \
# doc
# Feedback Model C22.docx -0.031201  0.007197  0.006651 -0.006528  0.019026
# Feedback Model D21.docx  0.034002  0.023909  0.013158 -0.011543  0.007245
# Feedback Model A22.docx -0.050843 -0.002922 -0.010184 -0.000999  0.035424
# Feedback Model B11.docx -0.005615 -0.023467  0.023844 -0.000942 -0.006770
# Feedback Model C12.docx -0.032257  0.007124  0.007268 -0.008886  0.018046
#
#                                99
# doc
# Feedback Model C22.docx  0.010656
# Feedback Model D21.docx -0.003051
# Feedback Model A22.docx  0.020685
# Feedback Model B11.docx  0.033466
# Feedback Model C12.docx  0.014084
#
# [5 rows x 100 columns]

# %% [markdown]
# # What to include in comparison dataframe

# %% [markdown]
# # Scripts

# %%
docs_of_interest = list(matrix_scripts[matrix_scripts.index.str.contains('Management')].index)
subset = matrix_scripts[matrix_scripts.index.isin(docs_of_interest)]
centroid = pd.DataFrame.mean(subset)
main_words = list(centroid.sort_values(ascending = False)[0:25].index)
centroid.sort_values(ascending = False)[0:25]
# Out:
# 0     0.534107
# 3     0.281866
# 1     0.142961
# 5     0.085712
# 15    0.074387
# 9     0.050855
# 16    0.046443
# 23    0.021229
# 13    0.018147
# 37    0.017594
# 51    0.016298
# 14    0.012467
# 18    0.010925
# 22    0.009963
# 78    0.009081
# 77    0.008419
# 11    0.007875
# 83    0.007649
# 21    0.007636
# 44    0.007581
# 95    0.007415
# 48    0.007145
# 62    0.006733
# 50    0.006304
# 53    0.005746
# dtype: float64

# %% [markdown]
# # Session Similarity

# %%
docs_of_interest = list(docs[(docs.year == '2017-18') & (docs.semester == 'spring')].index)
subset = matrix_transcripts[matrix_transcripts.index.isin(docs_of_interest)]
centroid = pd.DataFrame.mean(subset)
centroid.sort_values(ascending = False)[0:25]
# Out:
# 0     0.694130
# 1     0.186201
# 2     0.154583
# 5     0.118259
# 3     0.077101
# 7     0.034407
# 9     0.033888
# 4     0.032798
# 10    0.030913
# 38    0.014756
# 6     0.012886
# 15    0.010850
# 25    0.009252
# 58    0.008538
# 21    0.007919
# 35    0.007161
# 29    0.007092
# 30    0.006550
# 47    0.006295
# 64    0.006045
# 90    0.004889
# 41    0.004868
# 65    0.004674
# 31    0.004662
# 39    0.003903
# dtype: float64

# %%
docs_of_interest = list(docs[(docs.year == '2018-19') & (docs.semester == 'spring')].index)
subset = matrix_transcripts[matrix_transcripts.index.isin(docs_of_interest)]
centroid = pd.DataFrame.mean(subset)
centroid.sort_values(ascending = False)[0:25]
# Out:
# 0     0.694434
# 1     0.215121
# 8     0.072670
# 13    0.038896
# 20    0.031524
# 17    0.029531
# 32    0.027449
# 10    0.022609
# 28    0.022545
# 26    0.019460
# 37    0.015097
# 38    0.013114
# 43    0.012226
# 16    0.011560
# 36    0.010097
# 42    0.008914
# 65    0.008470
# 39    0.008346
# 29    0.007680
# 82    0.007296
# 67    0.006527
# 24    0.006452
# 85    0.006238
# 60    0.006234
# 59    0.005811
# dtype: float64

# %%
docs_of_interest = list(docs[(docs.year == '2019-20') & (docs.semester == 'fall')].index)
subset = matrix_transcripts[matrix_transcripts.index.isin(docs_of_interest)]
centroid = pd.DataFrame.mean(subset)
centroid.sort_values(ascending = False)[0:25]
# Out:
# 0     0.682255
# 1     0.168602
# 6     0.070664
# 15    0.047864
# 14    0.042876
# 11    0.021274
# 21    0.019872
# 24    0.018566
# 34    0.017365
# 30    0.015586
# 12    0.013086
# 33    0.012814
# 31    0.011715
# 17    0.011547
# 23    0.010193
# 62    0.010120
# 71    0.007899
# 22    0.007553
# 66    0.007256
# 46    0.006153
# 74    0.006113
# 52    0.005912
# 70    0.005653
# 53    0.005408
# 27    0.004943
# dtype: float64

# %% [markdown]
# # LSA Topics

# %%
topics = pd.read_csv(clean_filepath + topics_file, index_col = 0)

# %%
topics.nlargest(25, '0')
# Out:
#                  0         1         2         3         4         5  \
# think     0.290303 -0.288726  0.307304 -0.260755 -0.298365  0.170081
# want      0.269294  0.145140 -0.423291 -0.246695 -0.224892  0.042348
# right     0.268160  0.182677  0.010543 -0.072876  0.470688 -0.258122
# know      0.244968  0.110254  0.405732  0.234980  0.026845 -0.036548
# really    0.234931 -0.087126  0.064694 -0.031339  0.162888  0.457220
# say       0.176294  0.103234 -0.038536 -0.037306  0.020705 -0.216633
# ethan     0.165417  0.169069 -0.033515  0.042657  0.079517 -0.012874
# specific  0.155369  0.234052  0.072805  0.209065 -0.027028  0.141003
# one       0.151805  0.000934  0.054222  0.115979 -0.066228  0.032573
# could     0.143928 -0.028645  0.065376  0.110500 -0.045838 -0.199751
# would     0.137619 -0.017798  0.041672  0.039673  0.033603 -0.092121
# going     0.137416  0.066803 -0.106946 -0.293151 -0.009740 -0.126631
# good      0.137235 -0.109819  0.108554 -0.201308 -0.006838 -0.096526
# student   0.135174 -0.124206 -0.169960  0.220811 -0.030637 -0.032912
# let       0.134862  0.060556  0.021865  0.132585  0.098960 -0.115324
# text      0.131233 -0.426094 -0.143020  0.127505  0.292895  0.010066
# students  0.129520 -0.159182 -0.143216  0.089973 -0.115078  0.003928
# back      0.126047 -0.048616  0.036206 -0.112050  0.210328  0.188885
# time      0.125048  0.038043 -0.082031  0.014779 -0.036065  0.180719
# stop      0.124672  0.223340 -0.118660 -0.119487 -0.099328  0.005165
# well      0.114914 -0.103274  0.146328 -0.022523 -0.084351 -0.137512
# kind      0.114454 -0.051222  0.030181 -0.129117  0.181412 -0.025216
# great     0.106323 -0.079472 -0.048176  0.010666 -0.009305  0.028577
# make      0.103319 -0.036755 -0.119991  0.019845  0.011530  0.040884
# thing     0.102991  0.041198 -0.005710  0.045630 -0.016166  0.029006
#
#                  6         7         8         9  ...        90        91  \
# think    -0.018481  0.418044 -0.081922 -0.270389  ...  0.006533 -0.009785
# want      0.224921 -0.186020 -0.044240  0.003403  ...  0.012079  0.013866
# right    -0.025698  0.370433  0.234561  0.259105  ... -0.033100  0.000781
# know      0.332665 -0.376392  0.069307 -0.213931  ... -0.006570  0.017775
# really    0.059545 -0.208647  0.064031  0.325330  ...  0.008947 -0.011647
# say      -0.053297  0.050031 -0.199346 -0.021919  ...  0.025072 -0.054338
# ethan    -0.210166  0.192683 -0.067492 -0.147154  ... -0.032653 -0.008822
# specific  0.070653  0.107701 -0.169765  0.032382  ...  0.039726 -0.026298
# one       0.041871 -0.011178  0.014196  0.049639  ...  0.009339  0.010015
# could    -0.200667 -0.070368 -0.021276 -0.018876  ... -0.001292  0.062015
# would    -0.139449 -0.052615 -0.010879  0.031166  ...  0.014088  0.005332
# going     0.203610 -0.049568 -0.058500 -0.076620  ...  0.000602  0.016657
# good     -0.063160 -0.203471 -0.045539  0.251048  ... -0.023898  0.005165
# student   0.042860 -0.049240  0.022515  0.041093  ...  0.040984  0.000387
# let       0.036658  0.029871 -0.262085 -0.014773  ... -0.004493  0.018300
# text      0.069050  0.044146  0.020376 -0.237393  ... -0.010244  0.058858
# students -0.101569 -0.008997 -0.074505  0.057371  ...  0.042638  0.043295
# back     -0.054081 -0.014952 -0.127261 -0.101506  ... -0.020075  0.041050
# time     -0.179210 -0.037786  0.269113 -0.053551  ...  0.058011 -0.072258
# stop      0.028388  0.029067  0.151830 -0.160585  ... -0.009581  0.042518
# well     -0.042523 -0.059870  0.031289  0.169005  ... -0.012437 -0.036726
# kind     -0.230678 -0.315128  0.126604 -0.131547  ... -0.024628 -0.033312
# great    -0.171912 -0.044398 -0.223426 -0.035714  ...  0.022540  0.039803
# make      0.014383  0.001384  0.015886 -0.014635  ...  0.013997 -0.083090
# thing     0.089237  0.026567  0.079937  0.015319  ... -0.027870  0.025090
#
#                 92        93        94        95        96        97  \
# think    -0.005955  0.009738 -0.011316 -0.010695 -0.004343  0.004058
# want      0.002262 -0.003907  0.030467  0.012039  0.010090 -0.073639
# right    -0.004865  0.024009 -0.006461  0.021118  0.010036  0.010811
# know      0.014442  0.005820 -0.007384 -0.007785  0.012328 -0.007707
# really    0.050035  0.011772 -0.024591  0.003857  0.020148 -0.044815
# say       0.012730  0.010771  0.026288  0.007530  0.046693  0.012943
# ethan     0.002169 -0.014436 -0.004750  0.018297 -0.053273  0.002901
# specific  0.002765  0.046090 -0.042654 -0.036247 -0.066905  0.053194
# one       0.000934  0.039429  0.004543 -0.049234  0.088548  0.053501
# could    -0.025956  0.024775 -0.012652  0.007508  0.003386  0.013170
# would    -0.037380  0.007785  0.001543  0.033821 -0.005803 -0.004914
# going     0.010294  0.095422 -0.005220  0.000857 -0.035622  0.037921
# good      0.037587  0.030815 -0.028083  0.015911  0.005707 -0.018856
# student   0.006123 -0.006164  0.018799  0.048185 -0.066076 -0.013301
# let       0.035658  0.012860  0.056003 -0.005455  0.021488 -0.053828
# text      0.024160 -0.000530 -0.017782  0.015150 -0.059715 -0.015084
# students  0.030690 -0.018314  0.008249 -0.035430 -0.045548  0.043952
# back      0.057289 -0.015239 -0.029564  0.022044  0.034334 -0.020687
# time     -0.018106  0.025341  0.009263 -0.019582  0.046881  0.047175
# stop     -0.022072 -0.068413  0.017787  0.031037  0.038873 -0.002810
# well     -0.019499 -0.007011 -0.048775  0.006774 -0.070758 -0.011311
# kind     -0.025726 -0.004125 -0.018529 -0.010579 -0.045963  0.083675
# great     0.059550 -0.041325 -0.079931 -0.053340  0.039262  0.086699
# make     -0.030013  0.033215 -0.022059  0.008061 -0.035681  0.000754
# thing    -0.000578  0.032805  0.025659 -0.028931  0.011980  0.005332
#
#                 98        99
# think    -0.031055  0.008738
# want     -0.031721  0.001122
# right    -0.005159 -0.025566
# know     -0.034674 -0.009993
# really    0.038120  0.031309
# say       0.047580  0.019807
# ethan    -0.005846  0.022502
# specific  0.000442 -0.037511
# one       0.006756 -0.027164
# could    -0.059775  0.001325
# would    -0.001636  0.000910
# going     0.060934 -0.001074
# good     -0.009946  0.004225
# student   0.016878 -0.051675
# let       0.068297  0.054513
# text      0.015833  0.006402
# students -0.077355  0.033373
# back      0.031328 -0.047449
# time     -0.003866  0.029800
# stop     -0.029313  0.003148
# well      0.024451 -0.040556
# kind     -0.004634 -0.006961
# great    -0.038241  0.014042
# make     -0.001494  0.012202
# thing    -0.006929 -0.024572
#
# [25 rows x 100 columns]
